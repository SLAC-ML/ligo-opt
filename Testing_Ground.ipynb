# %%
from PSOoptimizer import main_wrapper_PSO_sim
from PSOoptimizer import main_wrapper_PSO_NN
from utils.finesse_base import base_kat

# %%
param = [-21,17]
test = main_wrapper_PSO_sim(param, base_kat)

# %%
names, powers = test
port = 'p_ITM_p2_i'
index_pick = names[0].index(port)
print("Calculating cost with port", port, "at index", index_pick)
out_power_pos = powers[0][index_pick]
out_power_D = powers[1][index_pick]
out_power_neg = powers[2][index_pick]
print(names[2][index_pick])
print(out_power_pos, out_power_D, out_power_neg)
# Out:
# Calculating cost with port p_ITM_p2_i at index 8
# p_ITM_p2_i
# 282.09409145046607 282.09409145046607 282.09409145046607
